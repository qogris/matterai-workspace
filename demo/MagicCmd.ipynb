# %%
# 使用 %matplotlib inline 内嵌显示 Matplotlib 图表
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %%
# %ls
# Out:
# data/  model.pth  plt.demo.ipynb  quickstart.ipynb  Untitled.ipynb

# %%
# %who
# Out:
# plt

# %%
# 使用 %time 测量代码执行时间
# %time sum([i for i in range(1000000)])
# Out:
# CPU times: user 60.8 ms, sys: 11.6 ms, total: 72.4 ms
# Wall time: 71.4 ms
# 499999500000

# %%
# %run plt.demo.ipynb
