# %%
# %pwd
# Out:
# '/home/opc/projects/demo'

# %%
import sys
print(sys.prefix)
# Out:
# /home/opc/anaconda3/envs/pt

# %%
def start_adventure():
    print("你进入了一个黑暗的洞穴...")
    action = input("你想往左走还是往右走？(左/右): ")

    if action == "左":
        print("你遇到了一个凶猛的龙！")
        fight = input("你想战斗还是逃跑？(战斗/逃跑): ")
        if fight == "战斗":
            print("你打败了龙，赢得了宝藏！")
        else:
            print("你成功逃脱，但失去了宝藏。")
    elif action == "右":
        print("你发现了一个秘密通道，逃了出去！")
    else:
        print("无效的输入，游戏结束。")

start_adventure()
# Out:
# 你进入了一个黑暗的洞穴...
# 你想往左走还是往右走？(左/右):  左
# 你遇到了一个凶猛的龙！

# %%
import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = c
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

def mandelbrot_set(xmin,xmax,ymin,ymax,width,height,max_iter):
    r1 = np.linspace(xmin, xmax, width)
    r2 = np.linspace(ymin, ymax, height)
    return (r1,r2,np.array([[mandelbrot(complex(r, i),max_iter) for r in r1] for i in r2]))

def display(xmin,xmax,ymin,ymax,width=10,height=10,max_iter=256):
    dpi = 80
    img_width = dpi * width
    img_height = dpi * height
    x,y,z = mandelbrot_set(xmin,xmax,ymin,ymax,img_width,img_height,max_iter)
    plt.imshow(z.T,origin='lower',cmap='hot',extent=[xmin,xmax,ymin,ymax])
    plt.show()

display(-2.0,0.5,-1.25,1.25)

# %%
import random

def guess_number_game():
    print("欢迎来到猜数字游戏！")
    
    # 生成一个 1 到 100 之间的随机数
    secret_number = random.randint(1, 100)
    attempts = 0

    while True:
        # 提示玩家输入猜测
        guess = input("请输入你猜测的数字（1-100）：")

        # 确保玩家输入的是数字
        if not guess.isdigit():
            print("请输入一个有效的数字！")
            continue
        
        guess = int(guess)
        attempts += 1

        # 检查玩家的猜测
        if guess < secret_number:
            print("你猜的数字太小了！")
        elif guess > secret_number:
            print("你猜的数字太大了！")
        else:
            print(f"恭喜你！你猜对了，数字是 {secret_number}。")
            print(f"你总共猜测了 {attempts} 次。")
            break

if __name__ == "__main__":
    guess_number_game()
# Out:
# 欢迎来到猜数字游戏！
# 请输入你猜测的数字（1-100）： 43
# 你猜的数字太小了！
# 请输入你猜测的数字（1-100）： 70
# 你猜的数字太小了！
# 请输入你猜测的数字（1-100）： 80
# 你猜的数字太小了！
# 请输入你猜测的数字（1-100）： 90
# 你猜的数字太小了！
# 请输入你猜测的数字（1-100）： 95
# 你猜的数字太大了！
# 请输入你猜测的数字（1-100）： 93
# 你猜的数字太大了！
# 请输入你猜测的数字（1-100）： 91
# 恭喜你！你猜对了，数字是 91。
# 你总共猜测了 7 次。

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 读取文本文件
with open('ThuVu.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# 生成词云
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# 显示词云
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
